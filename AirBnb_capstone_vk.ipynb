# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavrk18/AirBnb_EDA/blob/cleaning-and-visual-updates_vaibhav/AirBnb_capstone_vk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**   -

# %% [markdown]
# ##### **Project Type**    - AirBnb Bookings Analysis - EDA
# ##### **Contribution**    - Individual
# ##### **Vaibhav Kamble:** - kamblev378@gmail.com

# %% [markdown]
# ![Airbnb_Logo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vaibhavrk18/AirBnb_EDA.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# * In **Hospitality and Lodging industry** our project will be focused on analysing and data wrangling by using Pandas. visuals by using visualization libraries like Matplotlib and seaborn.
#
# * This could include data cleaning, transformation, integration.
#
#   1. Find all the duplicate values present in this dataset.
#   2. Find all Null Values present in this dataset.
#
#
#
# * **Describe Visualization Goals:** Different insights or patterns to uncover through data visualization? Describe how these visualizations will support your problem-solving efforts.
#
# * **Tools and Technologies:**
# This could include programming languages (Python), data manipulation libraries (Pandas, NumPy), visualization libraries (Matplotlib, Seaborn).
#
# **In the Hospitality and Lodging industry domain**, our project aims to address the issue of hosts and guest. We will perform data wrangling to clean and integrate hosts listing and guests needs. Through interactive visualizations using Python, Matplotlib and Seaborn, we intend to identify patterns. The success of our solution will be evaluated based on the spend of minimum_nights by individual guests and more number of listing from single hosts."

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# #####**Facilitate Accommodation Rentals:**
# Airbnb's primary objective is to enable hosts to list their properties or rooms for short-term rentals and allow travelers to find and book accommodations that suit their preferences and needs.
# #####**Enhance Traveler Choice:**
# Airbnb's objective is to provide travelers with a wide range of lodging options, allowing them to choose accommodations that align with their preferences, budgets, and travel styles.
# #####**Promote Sharing Economy:**
# Airbnb aims to promote the concept of the sharing economy, where individuals can utilize their underutilized assets (such as spare rooms or vacant properties) to generate income by renting them out to travelers.
# #####**Disrupt Traditional Hospitality:**
# By offering an alternative to traditional hotels and resorts, Airbnb aims to disrupt the conventional hospitality industry and provide a more personalized and localized approach to travel accommodations.
# #####**Generate Revenue:**
#  As a business, Airbnb's objective is to generate revenue by earning a commission or fee from both hosts and guests for each successful booking made through its platform.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime
from tabulate import tabulate

# %% [markdown]
# ### Dataset Loading

# %%
# mounting the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# dataset is loading using pandas as 'airbnb_df'
# read airbnb_df
filepath = "/content/drive/MyDrive/Almabetter/csv/Airbnb NYC 2019.csv"
airbnb_df = pd.read_csv(filepath)     # reading dataset using pandas read method.

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# 'airbnb_df.shape' will give the number of rows and columns in airbnb_df.
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# check if there are duplicate value present in airbnb_df dataset
duplicate_values = airbnb_df.duplicated().value_counts()
duplicate_values
# Out:
# False    48895
# dtype: int64

# %% [markdown]
# **OBSERVATION**
#
# *   There are no douplicate values in this dataset

# %%
# know the shape before dropping the duplicates.
airbnb_df.shape
# Out:
# (48895, 16)

# %%
# drop duplicated if present
# in this case airbnb_df has no duplicate records.
airbnb_df.drop_duplicates(inplace = True)

# %%
# after droping the duplicate records recheck the shape of airbnb_df
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# **OBSERVATION**
#
# another way to see the duplicate records.
# *   There is no change in record and fields' count after dropping the duplicagte values.
# *   Hence there are no duplicate records.

# %% [markdown]
# **VISUALIZATION OF DUPLICATE RECORDS.**

# %%
#Visualizing the duplicate values
plt.figure(figsize = (6,4))
plot = sns.countplot(x = airbnb_df.duplicated(),  # x = airbnb_df.duplicated()   #categorical distribution of duplicate values as True and False
                     width = 0.3,                    #width of column
                     palette = 'viridis',                 #color of column
                     alpha = None)                   #transparency value for column

for i, count in enumerate(duplicate_values):
  plot.text(i, count + 50, str(count),
            ha = 'center', va = 'top',     #ha = 'center', 'right', 'left'
            weight = 'bold')                        #va = 'top', 'bottom', 'center', 'baseline', 'center_baseline'

plt.xlabel("Boolean representation of duplicate values")
plt.title('Visualisation of duplicated value')
plt.ylabel('Duplicate Values')

plt.tight_layout()
plt.show()

print("\n\033[1mTHERE ARE NO DUPLICATE VALUES!!\033[0m") #\003[1m  \033[0m : bold string.
# Out:
# THERE ARE NO DUPLICATE VALUES!!

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Countx
missing_values = airbnb_df.isna().sum().sort_values(ascending = False).head().reset_index()
rename_missing_values = missing_values.rename(columns={0: 'Missing_Values_Count'})
rename_missing_values
# Out:
#                index  Missing_Values_Count
# 0        last_review                 10052
# 1  reviews_per_month                 10052
# 2          host_name                    21
# 3               name                    16
# 4                 id                     0

# %%
# bar plot
plt.figure(figsize = (8,5))
plot = sns.barplot(x = 'index',
                   y = 'Missing_Values_Count',
                   data = rename_missing_values,
                   width =0.6,
                   palette = 'rainbow',
                   alpha = None,
                   errorbar = None) # removing confidence interval
#(errobar is equivalent to the ci : None, The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.)

# loop through each bar in the plot
for p in plot.patches:                            #patches gives reference to the bar in barplot
    plot.annotate(format(p.get_height(), '.0f'),
                  (p.get_x() + p.get_width() / 2., p.get_height()), #create the coordinates
                  ha = 'center', va = 'center',   # horizontal and vertical alignments
                  xytext = (0, 5),
                  textcoords = 'offset points',
                  fontweight='bold')

plt.title('Fields With Missing Values', color = 'black', weight = 'bold')
plt.tight_layout()
plt.show()

# %%
# take look at name, host_name, room_type, reviews_per_month and last_review.

subset1 = airbnb_df.loc[:,['name','host_name','room_type','reviews_per_month','last_review']]
subset1.head()
# Out:
#                                                name    host_name  \
# 0                Clean & quiet apt home by the park         John
# 1                             Skylit Midtown Castle     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth
# 3                   Cozy Entire Floor of Brownstone  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park        Laura
#
#          room_type  reviews_per_month last_review
# 0     Private room               0.21  2018-10-19
# 1  Entire home/apt               0.38  2019-05-21
# 2     Private room                NaN         NaN
# 3  Entire home/apt               4.64  2019-07-05
# 4  Entire home/apt               0.10  2018-11-19

# %% [markdown]
# ###**Upper and Lower caping of reviews_per_month**

# %%
# creating the range between 5% to 95% in reviews_per_month.

lower_cap = airbnb_df['reviews_per_month'].quantile(0.05)
upper_cap = airbnb_df['reviews_per_month'].quantile(0.95)

print(f'lower capping of reviews_per_month is : {lower_cap}')
print(f'upper capping of reviews_per_month is : {upper_cap}')

print(f"\n5 to 95 percent of data from reviews_per_month lies in range {lower_cap} to {upper_cap} reviews per month")
# Out:
# lower capping of reviews_per_month is : 0.04
# upper capping of reviews_per_month is : 4.64
#
# 5 to 95 percent of data from reviews_per_month lies in range 0.04 to 4.64 reviews per month

# %% [markdown]
# **Count of OUTLIERS**

# %%
# lets take look at reviews_per_month column and see the distribution of reviews per month.
# check wheather outliers present or not!

# boxplot visualization:

plt.figure(figsize = (10,5))
sns.boxplot(data = airbnb_df,
            y = 'reviews_per_month',
            width = 0.6,
            x = 'room_type')

plt.title("Outliers Present")
plt.grid(True)
plt.show()

# %% [markdown]
# ```
# reviews_per_month data lies between 0.04 to 4.64
# ```

# %% [markdown]
# **NULL/NaN VALUES IMPUTATION WITH 0**
#
#
# Fields reviews_per_month and last_review are imputed with 0.

# %%
# subset2 is replace null values with 0
subset2 = airbnb_df.reviews_per_month.fillna(value = 0, inplace = True)
# subset3 is to replace NaN with 0
subset3 = airbnb_df.last_review.fillna(value = 0, inplace = True)

# %%
#taking look at the null values.
airbnb_df.isna().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *  AirBnb dataset contains **16 columns and 48895 records.**
# *  AirBnb dataset has **zero Duplicate values.**
# * AirBnb dataset has four columns which has the missing values in it ***last_review, reviews_per_month, host_name and name***, which contain ***10052, 10052, 21 and 16*** null values respectively.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# get the list of all column names from oroginal datset
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#Another way to take look at columns in table form
from tabulate import tabulate

# Extract the column names from the DataFrame
columns = airbnb_df.columns

# Create a DataFrame with a single column for column names
column_names_df = pd.DataFrame(columns, columns=['Column Names'])

# Use tabulate to format and print the DataFrame as a table
table = tabulate(column_names_df, headers='keys', tablefmt='simple', showindex=True)

# Print the formatted table
print(table)
# Out:
#     Column Names
# --  ------------------------------
#  0  id
#  1  name
#  2  host_id
#  3  host_name
#  4  neighbourhood_group
#  5  neighbourhood
#  6  latitude
#  7  longitude
#  8  room_type
#  9  price
# 10  minimum_nights
# 11  number_of_reviews
# 12  last_review
# 13  reviews_per_month
# 14  calculated_host_listings_count
# 15  availability_365

# %% [markdown]
# **DESCRIBE AIRBNB**

# %%
# Dataset Describe
airbnb_df.describe(include = 'all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ### Variables Description

# %%
# variable can be shown in tabular for by using python library tabulate

from tabulate import tabulate

# Define your data as a list of lists where each sublist contains column name and description
data = [
    ['id', 'Unique Guest ID'],
    ['name', 'Name of the listing'],
    ['host_id', 'Unique host_id'],
    ['host_name', 'Name of the host'],
    ['neighbourhood_group', 'Location'],
    ['neighbourhood', 'Area'],
    ['latitude', 'Latitude range'],
    ['longitude', 'Longitude range'],
    ['room_type', 'Type of listing'],
    ['price', 'Price of listing'],
    ['minimum_nights', 'Minimum nights to be paid for'],
    ['number_of_reviews', 'Number of reviews'],
    ['last_review', 'Content of the last review'],
    ['reviews_per_month', 'Number of checks per month'],
    ['calculated_host_listing_counts', 'Total count'],
    ['availability_365', 'Availability around the year']
]

# Define headers for the table
headers = ['Column Name', 'Description']

# Define headers for the table with ANSI escape codes for cyan text
headers = ['\033[36mColumn Name\033[0m', '\033[36mDescription\033[0m']

# Use tabulate to format and print the table
table = tabulate(data, headers, tablefmt='orgtbl') #tablefmt : pretty, grid, pipe, orgtbl, mediawiki, jira, github,

# Print the formatted table
print(table)
# Out:
# | Column Name                    | Description                   |
# |--------------------------------+-------------------------------|
# | id                             | Unique Guest ID               |
# | name                           | Name of the listing           |
# | host_id                        | Unique host_id                |
# | host_name                      | Name of the host              |
# | neighbourhood_group            | Location                      |
# | neighbourhood                  | Area                          |
# | latitude                       | Latitude range                |
# | longitude                      | Longitude range               |
# | room_type                      | Type of listing               |
# | price                          | Price of listing              |
# | minimum_nights                 | Minimum nights to be paid for |
# | number_of_reviews              | Number of reviews             |
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
from tabulate import tabulate

# Create a list to store the data in tabular format
table_data = []

# Find the maximum column name length for formatting
max_column_len = max(len(column) for column in airbnb_df.columns)

# Loop through each column and append data to the table
for column in airbnb_df.columns:
    unique_values_count = len(airbnb_df[column].unique())
    table_data.append([column, unique_values_count])

# Define headers for the table with ANSI escape codes for cyan text
headers = ['\033[34m Column Name \033[0m', '\033[34m Unique Values Count \033[0m']

# Use tabulate to format and print the table
print(tabulate(table_data, headers, tablefmt='pretty')) #tablefmt : rst, simple, pretty, grid, pipe, orgtbl, mediawiki, jira, github,
# Out:
# +--------------------------------+-----------------------+
# |          Column Name           |  Unique Values Count  |
# +--------------------------------+-----------------------+
# |               id               |         48895         |
# |              name              |         47906         |
# |            host_id             |         37457         |
# |           host_name            |         11453         |
# |      neighbourhood_group       |           5           |
# |         neighbourhood          |          221          |
# |            latitude            |         19048         |
# |           longitude            |         14718         |
# |           room_type            |           3           |
# |             price              |          674          |
# |         minimum_nights         |          109          |
# |       number_of_reviews        |          394          |
# |          last_review           |         1765          |
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ###Drop the null values from df.

# %%
airbnb_df.dropna(axis = 0, inplace = True)
# airbnb_df_1 = airbnb_df.drop(airbnb_df[airbnb_df['number_of_reviews'] == 0].index, inplace = True)
# take loot at null value present in airbnb_df_1 or not!

# %%
airbnb_df.shape
# Out:
# (48858, 16)

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48858 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48858 non-null  int64
#  3   host_name                       48858 non-null  object
#  4   neighbourhood_group             48858 non-null  object
#  5   neighbourhood                   48858 non-null  object
#  6   latitude                        48858 non-null  float64
#  7   longitude                       48858 non-null  float64
#  8   room_type                       48858 non-null  object
#  9   price                           48858 non-null  int64
#  10  minimum_nights                  48858 non-null  int64
#  11  number_of_reviews               48858 non-null  int64
# ...

# %% [markdown]
# **Rename the column from 'id' to 'guest_id'**

# %%
airbnb_df.rename(columns = {'id':'guest_id'}, inplace = True)

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# #####Q1 - top 10 Guest/guest_id who booked maximum_nights?

# %%
airbnb_df.groupby('guest_id').agg({'minimum_nights':'sum'}).sort_values('minimum_nights', ascending = False).head(10)
# Out:
#           minimum_nights
# guest_id
# 4204302             1250
# 20990053             999
# 30378211             999
# 10053943             999
# 8668115              500
# 6169897              500
# 5431845              500
# 35834935             500
# 11096888             500
# 8341919              480

# %% [markdown]
# #####Q2 - Which is the popular room_type in every aspects?

# %%
#popular room_types
airbnb_df.groupby('room_type').agg(max_nights_by_unique_guest_id = ('minimum_nights','max'),
                                   min_nights_by_unique_guest_id = ('minimum_nights','min'),
                                   average_night_spent = ('minimum_nights','mean'),
                                   average_room_price = ('price','mean'))
# Out:
#                  max_nights_by_unique_guest_id  min_nights_by_unique_guest_id  \
# room_type
# Entire home/apt                           1250                              1
# Private room                               999                              1
# Shared room                                999                              1
#
#                  average_night_spent  average_room_price
# room_type
# Entire home/apt             8.470090          211.806994
# Private room                5.380750           89.794360
# Shared room                 6.479724           70.075928

# %% [markdown]
# #####Q3 - Chart4 :Popular neighbourhood_group in every aspect?

# %%
#neighbourhood_group and minimum number_nights
#groupby on neighbourhood_group and sum of minimum_nights in each group
buroughs = airbnb_df.groupby('neighbourhood_group').agg(total_nights_spent = ('minimum_nights','sum'),
                                                        average_night_spent = ('minimum_nights','mean'),
                                                        max_nights_by_unique_guest_id = ('minimum_nights','max'),
                                                        min_nights_by_unique_guest_id = ('minimum_nights','min')).reset_index()

buroughs.sort_values('total_nights_spent', ascending = False)
# Out:
#   neighbourhood_group  total_nights_spent  average_night_spent  \
# 2           Manhattan              184792             8.538188
# 1            Brooklyn              121693             6.057693
# 3              Queens               29356             5.182910
# 0               Bronx                4971             4.564738
# 4       Staten Island                1802             4.831099
#
#    max_nights_by_unique_guest_id  min_nights_by_unique_guest_id
# 2                           1250                              1
# 1                            999                              1
# 3                            500                              1
# 0                            365                              1
# 4                            365                              1

# %% [markdown]
# #####Q4. chart - 7, What is the average price of room_type in each neighbourhood_group?

# %% [markdown]
# staten_island

# %%
staten_island_df = airbnb_df.loc[airbnb_df.loc[:,'neighbourhood_group'] == 'Staten Island']

# %%
staten_island_df.groupby('room_type').agg({'price':'mean'}).reset_index()
# Out:
#          room_type       price
# 0  Entire home/apt  173.846591
# 1     Private room   62.292553
# 2      Shared room   57.444444

# %% [markdown]
# manhattan

# %%
manhattan_df = airbnb_df.loc[airbnb_df.loc[:,'neighbourhood_group'] == 'Manhattan']

# %%
manhattan_df.groupby('room_type').agg({'price':'mean'}).reset_index()
# Out:
#          room_type       price
# 0  Entire home/apt  249.238211
# 1     Private room  116.805594
# 2      Shared room   88.977083

# %% [markdown]
# Brooklyn

# %%
brooklyn_df = airbnb_df.loc[airbnb_df.loc[:,'neighbourhood_group'] == 'Brooklyn']

# %%
brooklyn_df.groupby('room_type').agg({'price':'mean'}).reset_index()
# Out:
#          room_type       price
# 0  Entire home/apt  178.362609
# 1     Private room   76.510619
# 2      Shared room   50.527845

# %% [markdown]
# Queens

# %%
queens_df = airbnb_df.loc[airbnb_df.loc[:,'neighbourhood_group'] == 'Queens']

# %%
queens_df.groupby('room_type').agg({'price':'mean'}).reset_index()
# Out:
#          room_type       price
# 0  Entire home/apt  147.050573
# 1     Private room   71.776855
# 2      Shared room   69.020202

# %% [markdown]
# Bronx

# %%
bronx_df = airbnb_df.loc[airbnb_df.loc[:,'neighbourhood_group'] == 'Bronx']

# %%
bronx_df.groupby('room_type').agg({'price':'mean'}).reset_index()
# Out:
#          room_type       price
# 0  Entire home/apt  127.645503
# 1     Private room   66.788344
# 2      Shared room   58.610169

# %% [markdown]
# #####Q5 - Chart8: In which neighbourhood_group most of the hosts are located?

# %%
# Chart - 8 visualization code
max_host_located_in = airbnb_df.groupby('neighbourhood_group').agg({'host_id':'count'}).reset_index().rename(columns = {'host_id':'host_count'})
max_host_located_in.sort_values('host_count', ascending = False)
# Out:
#   neighbourhood_group  host_count
# 2           Manhattan       21643
# 1            Brooklyn       20089
# 3              Queens        5664
# 0               Bronx        1089
# 4       Staten Island         373

# %% [markdown]
# #####Q6 - Chart9: Top 10 host_name/host_id based on the reviews or availability_365?

# %%
# Q. which are the unique neighbourhood_groups?
# neighbourhood_group : location
# neighbourhood : (area) is a particular part of a town and the people who live there.
popular_host = airbnb_df.groupby(['host_id',
                                  'host_name',
                                  'room_type']).agg({'number_of_reviews':'sum',
                                                     'availability_365':'max',}).sort_values('number_of_reviews',
                                                                                             ascending = False).head(10)

top_10_host = popular_host.rename(columns = {'number_of_reviews':'total_review',
                                             'price':'mean_price',
                                             'availability_365':'availability_365'}).reset_index()

top_10_host
# Out:
#     host_id                       host_name     room_type  total_review  \
# 0  37312959                            Maya  Private room          2273
# 1    344035  Brooklyn&   Breakfast    -Len-  Private room          2205
# 2  35524316                    Yasu & Akiko  Private room          1837
# 3  40176101                           Brady  Private room          1818
# 4   4734398                              Jj  Private room          1798
# 5  26432133                        Danielle  Private room          1793
# 6  16677326                  Alex And Zeena  Private room          1355
# 7   6885157                           Randy  Private room          1323
# 8  23591164                          Angela  Private room          1269
# 9  59529529                             Han  Private room          1229
#
#    availability_365
# 0               175
# 1               339
# 2               305
# 3                70
# 4               342
# 5               347
# 6               362
# ...

# %% [markdown]
# ##### Q7. - Which host listed maximum number of properties?

# %%
# groupby on host_name and agg the total of calculated_host_listings_count

host_property_count = airbnb_df.groupby(['host_id',
                                         'host_name']).agg({'calculated_host_listings_count':'sum',
                                                            'price':'mean'}).reset_index().sort_values('calculated_host_listings_count',
                                                                                                       ascending = False).head(10)

host_property_count.rename(columns = {'calculated_host_listings_count':'total_properties_listed_by_host'})
# Out:
#          host_id          host_name  total_properties_listed_by_host  \
# 34615  219517861       Sonder (NYC)                           106929
# 29379  107434423         Blueground                            53824
# 19557   30283594               Kara                            14641
# 31050  137358866             Kazuya                            10609
# 14426   16098958     Jeremy & Laura                             9216
# 12796   12243051             Sonder                             9216
# 25637   61391963  Corporate Housing                             8281
# 17079   22541573                Ken                             7569
# 33837  200380610            Pranjal                             4225
# 9725     7503643               Vida                             2704
#
#             price
# 34615  253.195719
# 29379  303.150862
# 19557  277.528926
# 31050   43.825243
# 14426  208.958333
# 12796  213.031250
# 25637  146.241758
# 17079  215.436782
# 33837  290.230769
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **DATA CLEANING AND MANIPULATION**
# 1. extracted the duplicate values from dataset, I found that there were no duplicate values in the dataset.
# 2. found the null_values from the dataset, there were four columns in which null values were present.
# 3. drop the null values from the original dataset as inplace = True.
# 4. Replaced null values with 0.
# 5. found the average price of the each room_type from overall dataset.
# 6. found top 10 hosts which has highest reviews, more properties listed by individual hosts, which hosts available throughout the year.
# 7. which neighbourhood_group is popular to spend time in, etc.
#
# **some of the insights:**
#
# 1. manhattan is the famous/popular/demanded neighbourhood_group among other in every aspect of the guests.
# 2. average price of manhattan is highest than other neighbourhood_group.
# 3. host - 'michael' has the most number of reviews throughout the properties.
# 4. entire home/apt is the most famous room_type.
# 5. manhattan has the outliers in price where some of the properties costs way higher than other properties (i.e. 10000 per night)
# 6. Staten Island	is the least preferred neighbouthood_geoup among the five.
# 7. brooklyn is second most famous neighbouhood_group in reviews, availability_365 and host_listing_count.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### **Chart - 1 - Map of neighbourhood_group**

# %% [markdown]
# * **Manhattan** (co-extensive with New York County) is the geographically smallest and most densely populated borough; is the symbol of New York City.
#
# * **Brooklyn** (co-extensive with Kings County), on the western tip of Long Island, is the city's most populous borough. Brooklyn is known for its cultural, social, and ethnic diversity, an independent art scene, distinct neighborhoods, and a distinctive architectural heritage.
#
# * **Queens** (co-extensive with Queens County), on Long Island north and east of Brooklyn, is geographically the largest borough, the most ethnically diverse county in the United States, as well as the most ethnically diverse urban area in the world.
#
# * **The Bronx** (co-extensive with Bronx County) is New York City's northernmost borough and (apart from Marble Hill in the borough of Manhattan) the only New York City borough that is part of the United States mainland.
#
# * **Staten Island** (co-extensive with Richmond County) is generally the most suburban in character of the five boroughs.

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data = airbnb_df, x = 'latitude', y = 'longitude', hue = 'neighbourhood_group')
plt.title("map of neighbourhood_group",weight = 'bold')
plt.show()

# %% [markdown]
# distribution of room_type

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data = airbnb_df, x = 'latitude', y = 'longitude', hue = 'room_type')
plt.title("map of room_type",weight = 'bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to see the geographical coordinates of neighbourhood_group

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattab is the most densely populated and geographically smallest of the five boroughs of New York City.
# * wehre as the Queens is geographically the largest borough.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Staten island and Queens are less with population, hence availability of room is very frequent. hence on basis of availability and room_type new offer can be created to attract the guest.

# %% [markdown]
# #### **Chart - 2 - Where are most of the hosts located?**

# %%
# Chart - 8 visualization code
max_host_located_in = airbnb_df.groupby('neighbourhood_group')['host_name'].count().reset_index().rename(columns = {'host_name':'host_count'})
max_host_located_in.sort_values('host_count', ascending = False)
# Out:
#   neighbourhood_group  host_count
# 2           Manhattan       21643
# 1            Brooklyn       20089
# 3              Queens        5664
# 0               Bronx        1089
# 4       Staten Island         373

# %%
# bar plot
plt.figure(figsize = (8,5))
plot = sns.barplot(x = 'neighbourhood_group',
                   y = 'host_count',
                   data = max_host_located_in,
                   width =0.6,
                   palette = 'rainbow',
                   alpha = None,
                   errorbar = None) # removing confidence interval
#(errobar is equivalent to the ci : None, The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.)

# loop through each bar in the plot
for p in plot.patches:                            #patches gives reference to the bar in barplot
    plot.annotate(format(p.get_height(), '.0f'),
                  (p.get_x() + p.get_width() / 2., p.get_height()), #create the coordinates
                  ha = 'center', va = 'center',   # horizontal and vertical alignments
                  xytext = (0, 5),
                  textcoords = 'offset points',
                  fontweight='bold')

plt.title('Host count in each neighbourhood_group', color = 'black', weight = 'bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see the conposition of categorical vs numerical distribution i used bar plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Brooklyn and Manhattan two groups where most number of hosts are listed their properties.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Although Manhattan and Brooklyn are already famous and taking all spotlight by maximum listing. Queens comes 3rd place in terms of listing properties, Queens has the future scope of listing more properties and attract the guests to look and stay in Queens.
#
# It will be hard task to become top host in mahattan and brooklyn because of the avilability of maximum no of options for guests to book the property.
#
# here comes opportunity for hosts to list properties in Queens and become popular before the trend changes.

# %% [markdown]
# #### **Chart - 3 - Scatterplot Minimum_nights VS number_of_reviews**

# %%
#clusters creation
plt.figure(figsize = (10,6))
sns.scatterplot(x = 'minimum_nights',
                y = 'price',
                data = airbnb_df,
                hue = 'room_type',
                size = 'availability_365') # size of the bubble is changed based on the availability of the room_type.

plt.title("Minimum_nights VS Number_of_reviews)", weight = 'bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To see relation between how price is behaving with minimum_nights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   there is no correlation between minimum_nights and price.
# * it can be clearly seen that price range is very wide even if guest spends very less nights, and price is less for maximum nights booked
# * minimum_nights spend in entire home/apt is greater than 1200 which is an outlier in this case.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   there is no correlation between numerical variables. and hence no positive insights.
# *   Entire home/apt room_type has 3 count of minimum_night which is more than 400 and is outliers in this dataset. another room_type is private has 2 outliers minimum_nights more than 400.
# *prices are high even for less minimum_nights.

# %% [markdown]
# #### **Chart - 4 - Popular neighbourhood_group by minimum_nights**

# %%
# bar plot
plt.figure(figsize = (10,5))
plot = sns.barplot(x = 'neighbourhood_group',
                 y = 'minimum_nights',
                 data = airbnb_df,
                 width =0.6,
                 palette = 'magma',
                 alpha = None,
                 hue = 'room_type',
                 ci = None) # removing confidence interval


# loop through each bar in the plot
for p in plot.patches:                            #patches gives reference to the bar in barplot
    plot.annotate(format(p.get_height(), '.0f'),
                  (p.get_x() + p.get_width() / 2., p.get_height()), #create the coordinates
                  ha = 'center', va = 'center',   # horizontal and vertical alignments
                  xytext = (0, 5),
                  textcoords = 'offset points',
                  fontweight='bold')

plt.title('Popular neighbourhood_group by minimum_nights', color = 'black', weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-225-cb48951accb6>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   plot = sns.barplot(x = 'neighbourhood_group',

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   to see which neighbourhood_group has most number of minimum_nights. one is categorical variable and another is numberical hence used bar plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Manhattan and Brooklyn are the two neighbiurhood_group which are popular.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Manhattan and Brooklyn is popular in choice.
# * Entire home/apt is popular amongst other room_type.

# %% [markdown]
# #### **Chart - 5 - What is the average price of each room_type?**

# %%
# groupby on room_type and aggregate the mean of pirce
airbnb_df.groupby('room_type').agg({'price':'mean'}).sort_values('price', ascending = False,)
# Out:
#                       price
# room_type
# Entire home/apt  211.806994
# Private room      89.794360
# Shared room       70.075928

# %%
# bar plot
plt.figure(figsize = (8,5))
plot = sns.barplot(x = 'room_type',
                   y = 'price',
                   data = airbnb_df,
                   width =0.6,
                   palette = 'rainbow',
                   alpha = None,
                   errorbar = None) # removing confidence interval
#(errobar is equivalent to the ci : None, The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.)

# loop through each bar in the plot
for p in plot.patches:                            #patches gives reference to the bar in barplot
    plot.annotate(format(p.get_height(), '.0f'),
                  (p.get_x() + p.get_width() / 2., p.get_height()), #create the coordinates
                  ha = 'center', va = 'center',   # horizontal and vertical alignments
                  xytext = (0, 5),
                  textcoords = 'offset points',
                  fontweight='bold')

plt.title('Average price of each room_type', color = 'black', weight = 'bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to see the mean price of each room_type. it is a categorical vs numerical values presentation. hence i choose the bar plot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Entire home/apt is having the highest mean price which is 212

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes!
# If the minimum_nights count is also high in Entire home/apt then revenue collection will aslo be high.
# we'll check the distribution of minimum_nights over room_type and this  will give the more insights.

# %% [markdown]
# #### **Chart - 6 - Percentage of neighbourhood in neighbourhood_group**

# %%
# how many neighbourhood are there in each neighbourhoood_group
neighbourhood_group_df= airbnb_df.groupby('neighbourhood_group').agg({'neighbourhood':'count'}).sort_values('neighbourhood', ascending = False).reset_index()
neighbourhood_group_df
# Out:
#   neighbourhood_group  neighbourhood
# 0           Manhattan          21643
# 1            Brooklyn          20089
# 2              Queens           5664
# 3               Bronx           1089
# 4       Staten Island            373

# %%
data = airbnb_df['neighbourhood_group'].value_counts()

# Plot the pie chart without percentages
plt.figure(figsize=(8, 10))
plt.pie(data, labels=data.index,
        autopct='%1.1f%%',
        shadow=False,
        textprops={'fontsize': 15})

plt.title("Percentage of neighbourhood in each neighbourhood_group")

# Add a legend to show labels and percentages
plt.legend(data.index, title="Neighbourhood Group", loc="upper left")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see composition of neighbourhood over neighbourhood_groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan and Broooklyn has almost same number of neighbourhood present.
# * staten island has lowest number of neighbourhood.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Manhattan and Brooklyn has more possibility of host listing as it has the highest percentages of neighbourhood.

# %% [markdown]
# #### **Chart - 7 - Which is the best neighbourhood_group (location) acording to the average best price?**

# %%
# groupby on room_type and aggregate the mean of pirce
airbnb_df.groupby('neighbourhood_group').agg(average_price = ('price','mean')).sort_values('average_price', ascending = False,)
# Out:
#                      average_price
# neighbourhood_group
# Manhattan               196.897473
# Brooklyn                124.410523
# Staten Island           114.812332
# Queens                   99.536017
# Bronx                    87.469238

# %%
# bar plot
plt.figure(figsize = (10,5))
plot = sns.barplot(x = 'neighbourhood_group',
                   y = 'price',
                   data = airbnb_df,
                   width =0.7,
                   palette = 'rainbow',
                   alpha = None,
                   hue = 'room_type',
                   ci = None, # removing confidence interval
                   dodge = True)
#(errorbar is equivalent to ci : None, The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.)

# customize the legend and its location

# supported loc:'best','upper right','upper left',lower left','lower right','right','center left','center right','lower center','upper center','center'
plt.legend(title="room_type", loc="best", bbox_to_anchor=(1, 1)) # bbox_to_anchor = (x,y) x and y coordinates

# loop through each bar in the plot
for p in plot.patches:                            #patches gives reference to the bar in barplot
    plot.annotate(format(p.get_height(), '.0f'),
                  (p.get_x() + p.get_width() / 2., p.get_height()), #create the coordinates
                  ha = 'center', va = 'center',   # horizontal and vertical alignments
                  xytext = (0, 5),
                  textcoords = 'offset points',
                  fontweight='normal')

plt.title('Locatioin VS average price of each room_type', color = 'black', weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-243-7d9e6bf62d30>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   plot = sns.barplot(x = 'neighbourhood_group',

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see the categorical vs numerical distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Queens can be the best choice considering low budget.
# * Manhattab and Brooklyn are the expensive compared to other.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * average price of shared room is less than other. hence bachelor can be encourage to book the shared room not in Manhattan only but in any of the neighbourhood_group as average price is nearly the same.

# %% [markdown]
# #### **Chart - 8 Linelpot - number_of_reviews in each neighbourhood?**

# %%
airbnb_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-546143cad758> in <cell line: 1>()
# ----> 1 airbnb_df.head()
#
# NameError: name 'airbnb_df' is not defined

# %%
number_of_reviews = airbnb_df.groupby(['neighbourhood_group','neighbourhood','room_type'])['number_of_reviews'].sum().reset_index()
number_of_reviews
# Out:
#     neighbourhood_group  neighbourhood        room_type  number_of_reviews
# 0                 Bronx       Allerton  Entire home/apt                864
# 1                 Bronx       Allerton     Private room                939
# 2                 Bronx     Baychester  Entire home/apt                286
# 3                 Bronx     Baychester     Private room                 24
# 4                 Bronx        Belmont  Entire home/apt                 96
# ..                  ...            ...              ...                ...
# 535       Staten Island  West Brighton     Private room                352
# 536       Staten Island    Westerleigh  Entire home/apt                  1
# 537       Staten Island    Westerleigh     Private room                 17
# 538       Staten Island    Willowbrook  Entire home/apt                  9
# 539       Staten Island        Woodrow  Entire home/apt                  0
#
# [540 rows x 4 columns]

# %%
plt.figure(figsize = (12,5))
sns.lineplot(x = 'neighbourhood_group',
             y = 'number_of_reviews',
             data = number_of_reviews,
             hue = 'room_type')

plt.legend(title="room_type", loc="upper right") #, bbox_to_anchor=(0.4, 0.7) manual position of legend
#supported values for, loc = 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'
plt.xticks(rotation = 90)
plt.grid(True)

plt.title("Number of reviews in neighbourhood_group", weight = 'bold')

plt.tight_layout()
plt.show()

# %%
# top 10 neighbourhood by most reviews .

number_of_reviews_more_than_2k = number_of_reviews.loc[number_of_reviews.loc[:,'number_of_reviews'] >= 2000]
number_of_reviews_more_than_2k.sort_values('number_of_reviews',ascending = False).reset_index().head(10)
# Out:
#    index neighbourhood_group       neighbourhood        room_type  \
# 0    124            Brooklyn  Bedford-Stuyvesant  Entire home/apt
# 1    125            Brooklyn  Bedford-Stuyvesant     Private room
# 2    273           Manhattan              Harlem     Private room
# 3    239            Brooklyn        Williamsburg  Entire home/apt
# 4    240            Brooklyn        Williamsburg     Private room
# 5    146            Brooklyn            Bushwick     Private room
# 6    272           Manhattan              Harlem  Entire home/apt
# 7    258           Manhattan        East Village  Entire home/apt
# 8    276           Manhattan      Hell's Kitchen     Private room
# 9    275           Manhattan      Hell's Kitchen  Entire home/apt
#
#    number_of_reviews
# 0              64795
# 1              43965
# 2              43755
# 3              43575
# 4              41259
# 5              31071
# 6              30870
# 7              26666
# 8              26371
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see the trend of number of reviews per neighbourhood_group

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * trendline shows that average number of reviews for private room_type are greater than other two room_types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes!
#
# * Staten Island are not being encouraged to reviews shared room properties. while entire home/apt and private room are reviewed the most.

# %% [markdown]
# #### **Chart - 9 - Top 10 popular/demanded host based on the reviews or availability_365?**

# %%
# Q. which are the unique neighbourhood_groups?
# neighbourhood_group : location
# neighbourhood : (area) is a particular part of a town and the people who live there.
popular_host = airbnb_df.groupby(['host_name','room_type']).agg({'number_of_reviews':'sum',
                                                   'price':'mean',
                                                   'availability_365':'max'}).sort_values('number_of_reviews',
                                                                                            ascending = False).head(10)

top_10_host = popular_host.rename(columns = {'number_of_reviews':'total_review','price':'mean_price','availability_365':'availability_365'}).reset_index()

# %%
top_10_host
# Out:
#   host_name        room_type  total_review  mean_price  availability_365
# 0   Michael  Entire home/apt          6598  210.231076               365
# 1     David  Entire home/apt          4542  232.565421               365
# 2   Michael     Private room          4372   85.111842               365
# 3      John     Private room          4030   75.039216               365
# 4     Jason  Entire home/apt          3841  182.935897               365
# 5      Alex  Entire home/apt          3586  243.920000               365
# 6     David     Private room          3552   84.630435               365
# 7      Eric  Entire home/apt          3304  201.479452               364
# 8      John  Entire home/apt          3046  214.518519               365
# 9      Mike  Entire home/apt          2960  178.609929               365

# %%
plt.figure(figsize = (10,6))
plot = sns.barplot(x = 'host_name',
                   y = 'total_review',
                   data = top_10_host,
                   width =0.7,
                   palette = 'Blues',
                   alpha = None,
                   errorbar = None,# removing confidence interval, #(errobar is equivalent to the ci : None, The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.)
                   hue = 'room_type',
                   dodge=True) # create the stack of legend_category inside single bar instead of grouped bars.

# customize the legend and its location on main plot
plt.legend(title="room_type", loc="upper right", bbox_to_anchor=(1, 1)) # bbox_to_anchor = (x,y) x and y coordinates

# loop through each bar in the plot
for p in plot.patches:                            #patches gives reference to the bar in barplot
    plot.annotate(format(p.get_height(), '.0f'),
                  (p.get_x() + p.get_width() / 2, p.get_height()), #create the coordinates
                  ha = 'center', va = 'bottom',   # horizontal and vertical alignments
                  xytext = (0,2),
                  textcoords = 'offset points',
                  fontweight='bold')

plt.title('Top 10 hosts based on reviews and availability', color = 'black', weight = 'bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see the categorical vd numerical distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Host - Michael has the highest number of reviews recieved. where Mike is last in top_10 list.
#
# * Michael, David and John are three hosts who got reviews for their both the room_types (entire home/apt , private)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Actual reviews responses recieved by top_10 hosts will be very important to increase other hosts' bussiness.
# * both (positive and negative) the reviews will be impactfull.

# %% [markdown]
# #### **Chart - 10 - Room_type availability_365 where number_of_reviews are highest**

# %%
# sorted sirbnb_df on number of reviews and availability_365.
available_365 = airbnb_df.loc[:,['neighbourhood_group','room_type','number_of_reviews','availability_365']].sort_values('number_of_reviews', ascending = False)
available_365
# Out:
#       neighbourhood_group        room_type  number_of_reviews  \
# 11759              Queens     Private room                629
# 2031            Manhattan     Private room                607
# 2030            Manhattan     Private room                597
# 2015            Manhattan     Private room                594
# 13495              Queens     Private room                576
# ...                   ...              ...                ...
# 14481            Brooklyn     Private room                  0
# 4694            Manhattan     Private room                  0
# 14482           Manhattan     Private room                  0
# 26363           Manhattan  Entire home/apt                  0
# 48894           Manhattan     Private room                  0
#
#        availability_365
# 11759               333
# 2031                293
# 2030                342
# 2015                339
# 13495               173
# ...                 ...
# 14481                 0
# ...

# %%
# Chart - 10 visualization code

plt.figure(figsize = (10,5))
plot = sns.barplot(x = 'neighbourhood_group',
                   y = 'availability_365',
                   data = available_365,
                   palette='rainbow',
                   width = 0.6,
                   hue = 'room_type',
                   ci = None) #removing confidence interval

#"palette" refers to a collection of colors that are used to represent different categories or values in a plot.
#The 'viridis' palette is one such color palette that is designed to be perceptually uniform, making it effective for representing data with different levels or categories.

for p in plot.patches:
    plot.annotate(format(p.get_height(), '.0f'),
                  (p.get_x() + p.get_width() / 2., p.get_height()),
                  ha = 'center', va = 'center',   # va = 'top', 'bottom', 'center', 'baseline', 'center_baseline'
                  xytext = (0, 5),                # ha = 'center', 'right', 'left'
                  textcoords = 'offset points',
                  fontweight='bold')

plt.xlabel('neighbourhood_group', color = 'black', fontsize = 10, weight = 'bold')
plt.ylabel('availability_365',color = 'black', fontsize = 10, weight = 'bold')
plt.title('room availability', color = 'black', fontsize = 15, weight = 'bold')
plt.xticks(rotation = None)      # rotate the names of different categories in given angel.

#plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-259-c044bbd31eb2>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   plot = sns.barplot(x = 'neighbourhood_group',

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# barplot used beacause it is bivariate and it takes categorical and numerical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan has the less number of availability of days. whereas Queens and Staten Island has more availability.
# * shared room are available in maxium numbers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! it is possible to attract the bachelores who can share the space using shared room_type

# %% [markdown]
# #### **Chart - 11 - boxplot**
# **room_type and its review counts**

# %%
reviews= airbnb_df.loc[:,['neighbourhood_group','room_type','availability_365']].sort_values('availability_365', ascending = False)
reviews
# Out:
#       neighbourhood_group        room_type  availability_365
# 0                Brooklyn     Private room               365
# 43522           Manhattan  Entire home/apt               365
# 43696           Manhattan      Shared room               365
# 43695           Manhattan      Shared room               365
# 43675           Manhattan     Private room               365
# ...                   ...              ...               ...
# 16040           Manhattan  Entire home/apt                 0
# 24286           Manhattan  Entire home/apt                 0
# 24288           Manhattan     Private room                 0
# 16039           Manhattan  Entire home/apt                 0
# 26398           Manhattan  Entire home/apt                 0
#
# [48858 rows x 3 columns]

# %%
plt.figure(figsize = (10,5))
sns.boxplot(y = 'availability_365',
            x = 'room_type',
            data = reviews,
            hue = 'neighbourhood_group')


plt.title("Availability of room_type")
# y_ticks = [50,100,150,200] assign values to axis.
#plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.boxplot(y = 'availability_365',
            x = 'neighbourhood_group',
            data = reviews,
            hue = 'room_type')


plt.title("Availability of room_type in neighbourhood_group")
# y_ticks = [50,100,150,200] assign values to axis.
#plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see what is the range in which maximum or 50% of reviews lies in. hence used boxplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Upper whisker limit is lower than 150 reviews and 50% of reviews lies in 0 to 50 reviews and 25% in Q3 lies in 50 to 100 reviews. rest of the revies are outliers  means some of the reviews are exceptional in count.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Staten Island has the highest number of reviews in Entire home/apt and Shared room_type.
# * Queens has highest number of reviews as outliers in Private room_type.
# * Manhattan got the average number of reviews count thoughout the room_types but Entire home/apt has minimum number of reviews among other room_type.

# %% [markdown]
# #### **Chart - 12 - boxplot**

# %% [markdown]
# #####**1. price distribution over all neighbourhood_group**

# %%
plt.figure(figsize = (10,5))
sns.boxplot(x = 'neighbourhood_group',
            y = 'price',
            data = airbnb_df,
            hue = 'room_type')

plt.title("Price range in Quartiles")
# y_ticks = [50,100,150,200] assign values to axis.
#plt.grid(True)
plt.tight_layout()
plt.show()
plt.show()

# %% [markdown]
# #####**2. Outliers: from above boxplot it is clear that there are outliers present in price column. lets explore the outliers.**

# %%
# lets find the q3 values
q3= airbnb_df['price'].quantile(0.75)
q3

print(f"third quartile values: {q3}")
# Out:
# third quartile values: 175.0

# %%
# lets find q1 value
q1 = airbnb_df['price'].quantile(0.25)
q1

print(f"first quartile values: {q1}")
# Out:
# first quartile values: 69.0

# %%
# inter quartile range of boxplot
iqr = q3 - q1
iqr

print(f"inter quartile range values: {iqr}")
# Out:
# inter quartile range values: 106.0

# %%
# upper limit of the boxplot
upper_whisker = q3 + 1.5 * iqr
upper_whisker

print(f"upper whisker values: {upper_whisker}")
# Out:
# upper whisker values: 334.0

# %%
#lower limit of the boxplot
lower_whisker = q1 - 1.5 * iqr
lower_whisker

print(f"lower whisker values: {lower_whisker}")
# Out:
# lower whisker values: -90.0

# %% [markdown]
# now lets make the sesparate table of OUTLIERS where price > 321.5

# %%
outlier_table = airbnb_df.loc[airbnb_df.loc[:,'price'] > 321.5]
outlier_table.head()
# Out:
#      guest_id                                               name  host_id  \
# 61      15396                 Sunny & Spacious Chelsea Apartment    60278
# 85      19601                perfect for a family or small group    74303
# 103     23686  2000 SF 3br 2bath West Village private  townhouse    93790
# 114     26933  2 BR / 2 Bath Duplex Apt with patio! East Village    72062
# 116     26969                2 story family home in Williamsburg   115307
#
#      host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 61       Petra           Manhattan           Chelsea  40.74623  -73.99530
# 85      Maggie            Brooklyn  Brooklyn Heights  40.69723  -73.99268
# 103        Ann           Manhattan      West Village  40.73096  -74.00319
# 114      Bruce           Manhattan      East Village  40.72540  -73.98157
# 116  Alexandra            Brooklyn      Williamsburg  40.71942  -73.95748
#
# ...

# %%
#groupby on neighbourhood_group from outlier_table and some aggrigation.
outlier_table.groupby('neighbourhood_group').agg(average_price = ('price','mean'),
                                                 average_reviews_per_month = ('reviews_per_month','mean'),
                                                 average_night_spent = ('minimum_nights','mean'))
# Out:
#                      average_price  average_reviews_per_month  \
# neighbourhood_group
# Bronx                   464.000000                   0.812727
# Brooklyn                575.104015                   1.046661
# Manhattan               586.295172                   1.411462
# Queens                  650.424242                   1.300303
# Staten Island           527.000000                   0.055000
#
#                      average_night_spent
# neighbourhood_group
# Bronx                           2.000000
# Brooklyn                        5.633212
# Manhattan                       5.831724
# Queens                          4.787879
# Staten Island                   3.000000

# %% [markdown]
# #####**3. Since there are many price values which are outliers and actual price distribution is in low price range. hence taking sample of data where price is less than 600.**

# %%
price_df = airbnb_df.loc[airbnb_df.loc[:,'price'] <= 600]
price_df.loc[:,['neighbourhood_group','price','room_type']]
# Out:
#       neighbourhood_group  price        room_type
# 0                Brooklyn    149     Private room
# 1               Manhattan    225  Entire home/apt
# 2               Manhattan    150     Private room
# 3                Brooklyn     89  Entire home/apt
# 4               Manhattan     80  Entire home/apt
# ...                   ...    ...              ...
# 48890            Brooklyn     70     Private room
# 48891            Brooklyn     40     Private room
# 48892           Manhattan    115  Entire home/apt
# 48893           Manhattan     55      Shared room
# 48894           Manhattan     90     Private room
#
# [48080 rows x 3 columns]

# %%
# taking sample of data where price is less than 600.

plt.figure(figsize = (10,5))
sns.boxplot(y = 'price',
            x = 'neighbourhood_group',
            data = price_df,
            hue = 'room_type')


plt.title("Percentile of number_of_reviews")
# y_ticks = [50,100,150,200] assign values to axis.
#plt.grid(True)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see what is actual range where price is distributed. hence used boxplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Entire home/apt in Manhattan is expensive than other room_types which is expensive over all neighbourhood_group.
# * Shared room_type has lowest price range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * guests who wants to book Entire home/apt can seek for Queens, Staten Island and Bronx neighbourhood_group where price is less than 150.
# * giving offer can increase the guests count in Queens, Staten Island.
# * it is clear from outlier table that average price is much higher as compared with airbnb_df price distrinution.

# %% [markdown]
# #### **Chart - 13 - Histogram**

# %% [markdown]
# #####price distribution over aiabnb_df

# %%
# Chart - 13 visualization code

# Plot a histogram of 'total_review'
plt.figure(figsize=(15,5))
sns.histplot(data=airbnb_df,
             x='price',
             bins =100,
             kde=True,
             hue = 'room_type')

plt.legend(title="room_type", loc="best", bbox_to_anchor=(1, 1)) # bbox_to_anchor = (x,y) x and y coordinates

plt.title('Histogram of Price Distribution')
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #####Price distribution where sample data in which price is less than 500.

# %%
# price less than 500 subset.
price_hist = airbnb_df.loc[airbnb_df.loc[:,'price'] <= 500]
price_hist.head()
# Out:
#    guest_id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#histplot where price is less than 500.
plt.figure(figsize=(20,6))
sns.histplot(data=price_hist,
             x='price',
             bins =100,
             kde=True,
             hue = 'room_type')

plt.legend(title="room_type", loc="best", bbox_to_anchor=(1, 1)) # bbox_to_anchor = (x,y) x and y coordinates

plt.title('Histogram of Price Distribution')
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * to see the skiwness of price over neighbourhood_group

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Price is right skiwed of histograms and it shows the price is sitributed near to the minimum price and wehre price is greater than 500 are rares values of price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * most of the price is distributed in 20 to 250.

# %% [markdown]
# #### **Chart - 14 - Correlation Heatmap**

# %% [markdown]
# ##### **Control the annotations with a formatting string:** fmt=".1f"
# #####**Use a separate dataframe for the annotations:** annot=glue.rank(axis="columns")
# #####**Add lines between cells:** linewidth=.5
# #####**Select a different colormap by name:** cmap="crest"
# #####**Set the colormap norm (data values corresponding to minimum and maximum points):** vmin=50, vmax=100
# #####**cmap :** crest, viridis, inferno, magma, cividis, coolwarm, YlGnBu, Blues, Greens, Reds, Pastel1, Pastel2, rainbow.

# %%
# correlation table
correlation_table = airbnb_df.corr()
correlation_table
# Out:
# <ipython-input-277-62d4af401aba>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_table = airbnb_df.corr()
#                                 guest_id   host_id  latitude  longitude  \
# guest_id                        1.000000  0.588221 -0.003116   0.091076
# host_id                         0.588221  1.000000  0.020193   0.127198
# latitude                       -0.003116  0.020193  1.000000   0.084819
# longitude                       0.091076  0.127198  0.084819   1.000000
# price                           0.010564  0.015328  0.033944  -0.149954
# minimum_nights                 -0.012038 -0.017027  0.025893  -0.062893
# number_of_reviews              -0.320020 -0.140273 -0.015198   0.059151
# reviews_per_month               0.180095  0.209644 -0.018702   0.138759
# ...

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(15,6))
sns.heatmap(airbnb_df.corr(), fmt=".1f",annot=True, linewidth=0.5, cmap = 'Blues')
plt.title('Correlation of the columns', weight = 'bold')


plt.show()
# Out:
# <ipython-input-278-b3914de4f58b>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(airbnb_df.corr(), fmt=".1f",annot=True, linewidth=0.5, cmap = 'Blues')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Heatmap provide a clear and intuitive way to represent complex data patterns and relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * number_of_reviews has the negative correlation '-0.3'

# %% [markdown]
# #### **Chart - 15 - Pair Plot**

# %%
#take look at all columns names from airbnb_df
list(airbnb_df.columns)
# Out:
# ['guest_id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
#slice the required columns for pairplot.
pairplot_table = airbnb_df.loc[:,['neighbourhood_group',
                                  'neighbourhood',
                                  'room_type',
                                  'price',
                                  'minimum_nights',
                                  'number_of_reviews',
                                  'reviews_per_month',
                                  'calculated_host_listings_count',
                                  'availability_365']]

# %%
#take loot at the head of pairplot_table
pairplot_table.head()
# Out:
#   neighbourhood_group neighbourhood        room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington     Private room    149               1
# 1           Manhattan       Midtown  Entire home/apt    225               1
# 2           Manhattan        Harlem     Private room    150               3
# 3            Brooklyn  Clinton Hill  Entire home/apt     89               1
# 4           Manhattan   East Harlem  Entire home/apt     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0               0.00                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365
# 0               365
# 1               355
# ...

# %%
# bivariate analysis
# it gives the pairwise scatterplot and histograms for single numerical variable in single plot using pairplot.

# plot the pairplot on pairplot_table.
sns.pairplot(pairplot_table, hue = 'room_type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * instead of using scatterplot and histogram on individual variables. by using pairplot i can see the result in multiple plot at once.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * There is now correlation between any data available inside the airbnb_df.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * availability of Private and Entire home/apt room_type is very less is popular locations like Manhattan and Brooklyn. so hosts listed in Staten Island, Bronx and Queens should be encouraged to list their spared properties like entire home/apt and private room_type.
# * Shared room are most preferred room_types in Staten Island, Bronx and Queens so suggest hosts to raise the bar and set some high standards and provide good services so that revenue generation will increases.
# * Availability of Shared room_type is frequent in Manhattan and Brooklyn, host located in Manhattan and Brooklyn should come up with best offers to attract the guests from Staten Island, Bronx and Queens.
# * minimum_nights stay is high in Manhattan, perticularly for Entire home/apt room_type. this minimum_nights stay can be increased and encourage guests to spend extra time.
# * Repeated guests should be rewarded with some extra benefits and try to retain the guest for future by means of providing some offers to those guests.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Manhattan and Brooklyn are the most demanded neighbourhood_group based on their price and minimum_nights stay.
# * Most of the hosts are located in Manhattan and Brooklyn.
# * Entire home/apt has the highest average price.
# * Manhattan and Brooklyn has around 85% of neighbourhood in it.
# * Queens and Staten Island got the maximum number of reiews.
# * Staten Island is neighbourhood_group where populartion is less.
# * Shared room has less number of average reviews.
# * Availability of shared room_type is hight in Manhattan adn Brooklyn.
# * Michael, David, John, Jason, Alex, Eric and Mike are the top hosts based on number_of_reviews and availablility_365 respectively.
# * Staten Island, Queens and Bronx are the neighbourhood_group where availability_365 of private and Entire home/apt is high as compared to Manhattan and Brooklyn.
# * Availability_365 is less in Manhattana and Brooklyn specificaly for private room and entire home/apt room_type and shared room_type are available in big numbers.
# * Availability of Private and entire home/apt in Queens, Bronx and Staten island is more than Manhattan adn Brooklyn.
# * Shared room are preferred in staten island hence they are available in very less numbers.
# * Manhattan has the wide range of pricing avaible for room_type. in that Entire home/apt is the most expensive room_type and staten island is suitable for low budget guests where private room are frequently available.
# * **Bedford-Stuyvesant** has got the highest number of totat reviews "64795", Williumsburg, Bushwick, Harlem,	East Village and	Hell's Kitchen are the top 10 neighbourhoods.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
